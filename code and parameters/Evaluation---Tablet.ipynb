# %%
##################################################################################################
# Author：Yun Zheng
# Email：18848234471@163.com
# If there are any shortcomings, please forgive me,because this is my first time sharing.
##################################################################################################
# Data Augmentation - Grape
# package
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from skimage.metrics import structural_similarity as ssim
##################################################################################################
# 模型评价指标
import numpy as np
import pandas as pd
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt
from scipy.spatial.distance import euclidean
#合并药片数据集################
##加载原始数据集
df = pd.read_csv('tablet-3-4.csv', header=None)
yaopian1 = df.iloc[1:81, 1:].to_numpy()
yaopian2 = df.iloc[81:161, 1:].to_numpy()
yaopian = np.concatenate((yaopian1, yaopian2))
##加载每类Bootstrap生成数据集
df = pd.read_csv('3200_tablet_B.csv', header=None)
yaopian_B1 = df.iloc[0:1600, 0:].to_numpy()
yaopian_B2 = df.iloc[1600:3200, 0:].to_numpy()
yaopian_B = df.iloc[0:3200, 0:].to_numpy()
##加载每类GAN生成数据集
df = pd.read_csv('3200_G_yaopin.csv', header=None)
yaopian_G1 = df.iloc[0:1600, 0:].to_numpy()
yaopian_G2 = df.iloc[1600:3200, 0:].to_numpy()
yaopian_G = df.iloc[0:3200, 0:].to_numpy()
##合并B-G形式的数据集
yaopian_B_G_1 = np.concatenate((yaopian_B1, yaopian_G1))
yaopian_B_G_2 = np.concatenate((yaopian_B2, yaopian_G2))
yaopian_B_G = np.concatenate((yaopian_B_G_1, yaopian_B_G_2))
##合并Y-B-G形式的数据集
yaopian_Y_B_G_1 = np.concatenate((yaopian1, yaopian_B1, yaopian_G1))
yaopian_Y_B_G_2 = np.concatenate((yaopian2, yaopian_B2, yaopian_G2))
yaopian_Y_B_G = np.concatenate((yaopian_Y_B_G_1, yaopian_Y_B_G_2))
###Y-B
df = pd.read_csv('3360_Y_B_yaopin.csv', header=None)
yaopian_Y_B = df.iloc[0:3360, 0:].to_numpy()
###Y-G
df = pd.read_csv('3360_Y_G_yaopin.csv', header=None)
yaopian_Y_G = df.iloc[0:3360, 0:].to_numpy()
###############################################################################################
####计算Bootstrap的评价指标
avg_yaopian = np.mean(yaopian, axis=0)
avg_yaopian_B = np.mean(yaopian_B, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_B)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_B, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_B).max()
print(chebyshev_distance)

####计算GAN的评价指标
avg_yaopian = np.mean(yaopian, axis=0)
avg_yaopian_G = np.mean(yaopian_G, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_G)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_G, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_G).max()
print(chebyshev_distance)

####计算Bootstrap---GAN的评价指标
avg_yaopian = np.mean(yaopian, axis=0)
avg_yaopian_B_G = np.mean(yaopian_B_G, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_B_G)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_B_G, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_B_G).max()
print(chebyshev_distance)

####计算Y--B的评价指标
avg_yaopian = np.mean(yaopian, axis=0)
avg_yaopian_Y_B = np.mean(yaopian_Y_B, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_Y_B)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_Y_B, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_Y_B).max()
print(chebyshev_distance)

####计算Y--G的评价指标
avg_yaopian = np.mean(yaopian, axis=0)
avg_yaopian_Y_G = np.mean(yaopian_Y_G, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_Y_G)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_Y_G, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_Y_G).max()
print(chebyshev_distance)

####计算Y-B-G的评价指标
avg_yaopian = np.mean(yaopian, axis=0)
avg_yaopian_Y_B_G = np.mean(yaopian_Y_B_G, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_Y_B_G)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_Y_B_G, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_Y_B_G).max()
print(chebyshev_distance)
###############################################################################################
