# %%
##################################################################################################
# Author：Yun Zheng
# Email：18848234471@163.com
# If there are any shortcomings, please forgive me,because this is my first time sharing.
##################################################################################################
# Data Augmentation - Grape
# package
import numpy as np
import pandas as pd
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt
from scipy.spatial.distance import euclidean

##加载原始数据集
df = pd.read_excel('putao.xlsx', header=None)
putao1 = df.iloc[1:21, 1:].to_numpy()
putao2 = df.iloc[21:41, 1:].to_numpy()
putao3 = df.iloc[41:61, 1:].to_numpy()
putao4 = df.iloc[61:81, 1:].to_numpy()
putao5 = df.iloc[81:101, 1:].to_numpy()
putao6 = df.iloc[101:121, 1:].to_numpy()
putao7 = df.iloc[121:141, 1:].to_numpy()
putao8 = df.iloc[141:161, 1:].to_numpy()
putao9 = df.iloc[161:181, 1:].to_numpy()
putao10 = df.iloc[181:201, 1:].to_numpy()
putao11 = df.iloc[201:221, 1:].to_numpy()
putao12 = df.iloc[221:241, 1:].to_numpy()
putao13 = df.iloc[241:261, 1:].to_numpy()
putao14 = df.iloc[261:281, 1:].to_numpy()
putao15 = df.iloc[281:301, 1:].to_numpy()
putao16 = df.iloc[301:321, 1:].to_numpy()
putao17 = df.iloc[321:341, 1:].to_numpy()
putao18 = df.iloc[341:361, 1:].to_numpy()
putao19 = df.iloc[361:381, 1:].to_numpy()
putao20 = df.iloc[381:401, 1:].to_numpy()
putao = df.iloc[1:401, 1:].to_numpy()
##加载每类Bootstrap生成数据集
df1 = pd.read_csv('8000-B-putao.csv', header=None)
putao_B_1 = df1.iloc[1:401, 1:].to_numpy()
putao_B_2 = df1.iloc[401:801, 1:].to_numpy()
putao_B_3 = df1.iloc[801:1201, 1:].to_numpy()
putao_B_4 = df1.iloc[1201:1601, 1:].to_numpy()
putao_B_5 = df1.iloc[1601:2001, 1:].to_numpy()
putao_B_6 = df1.iloc[2001:2401, 1:].to_numpy()
putao_B_7 = df1.iloc[2401:2801, 1:].to_numpy()
putao_B_8 = df1.iloc[2801:3201, 1:].to_numpy()
putao_B_9 = df1.iloc[3201:3601, 1:].to_numpy()
putao_B_10 = df1.iloc[3601:4001, 1:].to_numpy()
putao_B_11 = df1.iloc[4001:4401, 1:].to_numpy()
putao_B_12 = df1.iloc[4401:4801, 1:].to_numpy()
putao_B_13 = df1.iloc[4801:5201, 1:].to_numpy()
putao_B_14 = df1.iloc[5201:5601, 1:].to_numpy()
putao_B_15 = df1.iloc[5601:6001, 1:].to_numpy()
putao_B_16 = df1.iloc[6001:6401, 1:].to_numpy()
putao_B_17 = df1.iloc[6401:6801, 1:].to_numpy()
putao_B_18 = df1.iloc[6801:7201, 1:].to_numpy()
putao_B_19 = df1.iloc[7201:7601, 1:].to_numpy()
putao_B_20 = df1.iloc[7601:8001, 1:].to_numpy()
putao_B = df1.iloc[1:8001, 1:].to_numpy()
##加载每类GAN生成数据集
df1 = pd.read_csv('8000--G--putao.csv', header=None)
putao_G_1 = df1.iloc[1:401, 1:].to_numpy()
putao_G_2 = df1.iloc[401:801, 1:].to_numpy()
putao_G_3 = df1.iloc[801:1201, 1:].to_numpy()
putao_G_4 = df1.iloc[1201:1601, 1:].to_numpy()
putao_G_5 = df1.iloc[1601:2001, 1:].to_numpy()
putao_G_6 = df1.iloc[2001:2401, 1:].to_numpy()
putao_G_7 = df1.iloc[2401:2801, 1:].to_numpy()
putao_G_8 = df1.iloc[2801:3201, 1:].to_numpy()
putao_G_9 = df1.iloc[3201:3601, 1:].to_numpy()
putao_G_10 = df1.iloc[3601:4001, 1:].to_numpy()
putao_G_11 = df1.iloc[4001:4401, 1:].to_numpy()
putao_G_12 = df1.iloc[4401:4801, 1:].to_numpy()
putao_G_13 = df1.iloc[4801:5201, 1:].to_numpy()
putao_G_14 = df1.iloc[5201:5601, 1:].to_numpy()
putao_G_15 = df1.iloc[5601:6001, 1:].to_numpy()
putao_G_16 = df1.iloc[6001:6401, 1:].to_numpy()
putao_G_17 = df1.iloc[6401:6801, 1:].to_numpy()
putao_G_18 = df1.iloc[6801:7201, 1:].to_numpy()
putao_G_19 = df1.iloc[7201:7601, 1:].to_numpy()
putao_G_20 = df1.iloc[7601:8001, 1:].to_numpy()
putao_G = df1.iloc[1:8001, 1:].to_numpy()
##合并B-G形式的数据集
putao_B_G_1 = np.concatenate((putao_B_1, putao_G_1))
putao_B_G_2 = np.concatenate((putao_B_2, putao_G_2))
putao_B_G_3 = np.concatenate((putao_B_3, putao_G_3))
putao_B_G_4 = np.concatenate((putao_B_4, putao_G_4))
putao_B_G_5 = np.concatenate((putao_B_5, putao_G_5))
putao_B_G_6 = np.concatenate((putao_B_6, putao_G_6))
putao_B_G_7 = np.concatenate((putao_B_7, putao_G_7))
putao_B_G_8 = np.concatenate((putao_B_8, putao_G_8))
putao_B_G_9 = np.concatenate((putao_B_9, putao_G_9))
putao_B_G_10 = np.concatenate((putao_B_10, putao_G_10))
putao_B_G_11 = np.concatenate((putao_B_11, putao_G_11))
putao_B_G_12 = np.concatenate((putao_B_12, putao_G_12))
putao_B_G_13 = np.concatenate((putao_B_13, putao_G_13))
putao_B_G_14 = np.concatenate((putao_B_14, putao_G_14))
putao_B_G_15 = np.concatenate((putao_B_15, putao_G_15))
putao_B_G_16 = np.concatenate((putao_B_16, putao_G_16))
putao_B_G_17 = np.concatenate((putao_B_17, putao_G_17))
putao_B_G_18 = np.concatenate((putao_B_18, putao_G_18))
putao_B_G_19 = np.concatenate((putao_B_19, putao_G_19))
putao_B_G_20 = np.concatenate((putao_B_20, putao_G_20))
putao_B_G = np.concatenate((putao_B_G_1, putao_B_G_2, putao_B_G_3, putao_B_G_4, putao_B_G_5, putao_B_G_6, putao_B_G_7, putao_B_G_8, putao_B_G_9, putao_B_G_10, putao_B_G_11, putao_B_G_12, putao_B_G_13, putao_B_G_14, putao_B_G_15, putao_B_G_16, putao_B_G_17, putao_B_G_18, putao_B_G_19, putao_B_G_20))
##合并Y-B-G形式的数据集
putao_Y_B_G_1 = np.concatenate((putao1, putao_B_1, putao_G_1))
putao_Y_B_G_2 = np.concatenate((putao2, putao_B_2, putao_G_2))
putao_Y_B_G_3 = np.concatenate((putao3, putao_B_3, putao_G_3))
putao_Y_B_G_4 = np.concatenate((putao4, putao_B_4, putao_G_4))
putao_Y_B_G_5 = np.concatenate((putao5, putao_B_5, putao_G_5))
putao_Y_B_G_6 = np.concatenate((putao6, putao_B_6, putao_G_6))
putao_Y_B_G_7 = np.concatenate((putao7, putao_B_7, putao_G_7))
putao_Y_B_G_8 = np.concatenate((putao8, putao_B_8, putao_G_8))
putao_Y_B_G_9 = np.concatenate((putao9, putao_B_9, putao_G_9))
putao_Y_B_G_10 = np.concatenate((putao10, putao_B_10, putao_G_10))
putao_Y_B_G_11 = np.concatenate((putao11, putao_B_11, putao_G_11))
putao_Y_B_G_12 = np.concatenate((putao12, putao_B_12, putao_G_12))
putao_Y_B_G_13 = np.concatenate((putao13, putao_B_13, putao_G_13))
putao_Y_B_G_14 = np.concatenate((putao14, putao_B_14, putao_G_14))
putao_Y_B_G_15 = np.concatenate((putao15, putao_B_15, putao_G_15))
putao_Y_B_G_16 = np.concatenate((putao16, putao_B_16, putao_G_16))
putao_Y_B_G_17 = np.concatenate((putao17, putao_B_17, putao_G_17))
putao_Y_B_G_18 = np.concatenate((putao18, putao_B_18, putao_G_18))
putao_Y_B_G_19 = np.concatenate((putao19, putao_B_19, putao_G_19))
putao_Y_B_G_20 = np.concatenate((putao20, putao_B_20, putao_G_20))
putao_Y_B_G = np.concatenate((putao_Y_B_G_1, putao_Y_B_G_2, putao_Y_B_G_3, putao_Y_B_G_4, putao_Y_B_G_5, putao_Y_B_G_6, putao_Y_B_G_7, putao_Y_B_G_8, putao_Y_B_G_9, putao_Y_B_G_10, putao_Y_B_G_11, putao_Y_B_G_12, putao_Y_B_G_13, putao_Y_B_G_14, putao_Y_B_G_15, putao_Y_B_G_16, putao_Y_B_G_17, putao_Y_B_G_18, putao_Y_B_G_19,putao_Y_B_G_20))
###Y-B
putao_Y_B_1 = np.concatenate((putao1, putao_B_1))
putao_Y_B_2 = np.concatenate((putao2, putao_B_2))
putao_Y_B_3 = np.concatenate((putao3, putao_B_3))
putao_Y_B_4 = np.concatenate((putao4, putao_B_4))
putao_Y_B_5 = np.concatenate((putao5, putao_B_5))
putao_Y_B_6 = np.concatenate((putao6, putao_B_6))
putao_Y_B_7 = np.concatenate((putao7, putao_B_7))
putao_Y_B_8 = np.concatenate((putao8, putao_B_8))
putao_Y_B_9 = np.concatenate((putao9, putao_B_9))
putao_Y_B_10 = np.concatenate((putao10, putao_B_10))
putao_Y_B_11 = np.concatenate((putao11, putao_B_11))
putao_Y_B_12 = np.concatenate((putao12, putao_B_12))
putao_Y_B_13 = np.concatenate((putao13, putao_B_13))
putao_Y_B_14 = np.concatenate((putao14, putao_B_14))
putao_Y_B_15 = np.concatenate((putao15, putao_B_15))
putao_Y_B_16 = np.concatenate((putao16, putao_B_16))
putao_Y_B_17 = np.concatenate((putao17, putao_B_17))
putao_Y_B_18 = np.concatenate((putao18, putao_B_18))
putao_Y_B_19 = np.concatenate((putao19, putao_B_19))
putao_Y_B_20 = np.concatenate((putao20, putao_B_20))
putao_Y_B = np.concatenate((putao_Y_B_1, putao_Y_B_2,putao_Y_B_3, putao_Y_B_4, putao_Y_B_5, putao_Y_B_6, putao_Y_B_7, putao_Y_B_8, putao_Y_B_9, putao_Y_B_10, putao_Y_B_11, putao_Y_B_12, putao_Y_B_13, putao_Y_B_14, putao_Y_B_15, putao_Y_B_16, putao_Y_B_17, putao_Y_B_18, putao_Y_B_19, putao_Y_B_20))
###Y-G
df = pd.read_csv('8400--Y_G--putao.csv', header=None)
putao_Y_G = df.iloc[0:8400, 0:].to_numpy()
###############################################################################################
###############################################################################################
####计算Bootstrap的评价指标
avg_yaopian = np.mean(putao, axis=0)
avg_yaopian_B = np.mean(putao_B, axis=0)

correlation = np.corrcoef(avg_yaopian, avg_yaopian_B)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_B, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_B).max()
print(chebyshev_distance)

####计算GAN的评价指标
avg_yaopian = np.mean(putao, axis=0)
avg_yaopian_G = np.mean(putao_G, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_G)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_G, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_G).max()
print(chebyshev_distance)

####计算Bootstrap---GAN的评价指标
avg_yaopian = np.mean(putao, axis=0)
avg_yaopian_B_G = np.mean(putao_B_G, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_B_G)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_B_G, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_B_G).max()
print(chebyshev_distance)

####计算Y--B的评价指标
avg_yaopian = np.mean(putao, axis=0)
avg_yaopian_Y_B = np.mean(putao_Y_B, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_Y_B)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_Y_B, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_Y_B).max()
print(chebyshev_distance)

####计算Y--G的评价指标
avg_yaopian = np.mean(putao, axis=0)
avg_yaopian_Y_G = np.mean(putao_Y_G, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_Y_G)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_Y_G, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_Y_G).max()
print(chebyshev_distance)

####计算Y-B-G的评价指标
avg_yaopian = np.mean(putao, axis=0)
avg_yaopian_Y_B_G = np.mean(putao_Y_B_G, axis=0)
# 假设Z和S分别是形状为（70，601）的numpy数组
correlation = np.corrcoef(avg_yaopian, avg_yaopian_Y_B_G)[0, 1]
print(correlation)
#####平均光谱SSIM值
# 计算Z和S的SSIM值
ssim_value, _ = ssim(avg_yaopian, avg_yaopian_Y_B_G, full=True, data_range=np.max(avg_yaopian) - np.min(avg_yaopian))
print(ssim_value)
# 计算切比雪夫距离
chebyshev_distance = np.abs(avg_yaopian - avg_yaopian_Y_B_G).max()
print(chebyshev_distance)
